# %%
import pandas as pd

df = pd.read_csv('mifkad2022.csv')

df.head()
# Out:
#   LocNameHeb  LocalityCode  StatArea StatAreaCmb  pop_approx  change_pcnt  \
# 0   כלל ארצי           NaN       NaN         NaN     9601720         26.7
# 1    אבו גוש         472.0       NaN         NaN        8660         39.8
# 2   אבו סנאן         473.0       NaN         NaN       13900         13.4
# 3   אבו סנאן         473.0       1.0           1        5100          NaN
# 4   אבו סנאן         473.0       2.0           2        3250          NaN
#
#    pop_density  religion ReligionHeb  sexRatio  ...  hh0_5_pcnt  hh18_24_pcnt  \
# 0          NaN         1      יהודים      99.2  ...        22.6          22.3
# 1       6558.4         2     מוסלמים     114.3  ...        26.4          37.5
# 2       6015.2         2     מוסלמים     108.0  ...        25.2          30.8
# 3          NaN         5      דרוזים      99.8  ...        28.7          27.6
# 4          NaN         2     מוסלמים     102.0  ...        19.9          33.8
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3379 entries, 0 to 3378
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   LocNameHeb            3379 non-null   object
#  1   LocalityCode          3378 non-null   float64
#  2   StatArea              2193 non-null   float64
#  3   StatAreaCmb           2193 non-null   object
#  4   pop_approx            3379 non-null   int64
#  5   change_pcnt           1162 non-null   float64
#  6   pop_density           1184 non-null   float64
#  7   religion              3379 non-null   int64
#  8   ReligionHeb           3379 non-null   object
#  9   sexRatio              3379 non-null   float64
#  10  inst_pcnt             338 non-null    float64
#  11  Foreign_pcnt          1067 non-null   float64
#  12  age0_19_pcnt          3379 non-null   float64
#  13  age20_64_pcnt         3379 non-null   float64
# ...

# %%
df = df[['LocNameHeb','LocalityCode','pop_approx','hh_total_approx','size_avg','religion','ReligionHeb','age20_64_pcnt','age_median']]

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3379 entries, 0 to 3378
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   LocNameHeb       3379 non-null   object
#  1   LocalityCode     3378 non-null   float64
#  2   pop_approx       3379 non-null   int64
#  3   hh_total_approx  3376 non-null   float64
#  4   size_avg         3376 non-null   float64
#  5   religion         3379 non-null   int64
#  6   ReligionHeb      3379 non-null   object
#  7   age20_64_pcnt    3379 non-null   float64
#  8   age_median       3379 non-null   float64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 237.7+ KB

# %%
df.head()
# Out:
#   LocNameHeb  LocalityCode  pop_approx  hh_total_approx  size_avg  religion  \
# 0   כלל ארצי           NaN     9601720        3053450.0       3.0         1
# 1    אבו גוש         472.0        8660           2400.0       3.4         2
# 2   אבו סנאן         473.0       13900           3930.0       3.5         2
# 3   אבו סנאן         473.0        5100           1210.0       3.9         5
# 4   אבו סנאן         473.0        3250            860.0       3.3         2
#
#   ReligionHeb  age20_64_pcnt  age_median
# 0      יהודים           52.2        30.0
# 1     מוסלמים           60.7        28.0
# 2     מוסלמים           59.5        29.0
# 3      דרוזים           58.4        29.0
# 4     מוסלמים           62.2        29.0
